# %% [markdown]
# <a href="https://colab.research.google.com/github/AyanPulpit/CarPool/blob/main/Car_Pool_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
import random
import numpy as np
from sklearn.cluster import KMeans

# Create a map centered around Ahmedabad, India
m = folium.Map(location=[23.0225, 72.5714], zoom_start=12)

# Sample data
employee_data = {
    'Employee 1' : [(23.040569325534438, 72.57062706914304), (23.205985370775075, 72.6003383541139)],
'Employee 2' : [(23.07632647838305, 72.56552245625252), (23.171857266222133, 72.62751931419916)],
'Employee 3' : [(22.989112336922705, 72.46964428299829), (23.18260732010498, 72.62723889345507)],
'Employee 4' : [(23.02417901877211, 72.57186554058606), (23.16352509228224, 72.68332161723087)],
'Employee 5' : [(23.00901888853867, 72.617079348103), (23.208597229520617, 72.64823866052438)],
'Employee 6' : [(23.078033252982657, 72.64773311367398), (23.200641990770578, 72.69063970299557)],
'Employee 7' : [(23.038632157469934, 72.59027710112873), (23.193646609574092, 72.67775866171466)],
'Employee 8' : [(23.020944816831072, 72.57958390343227), (23.195759118547777, 72.61668267252476)],
'Employee 9' : [(23.06582433260758, 72.61690821360212), (23.154605331778818, 72.62983128912366)],
'Employee 10' : [(23.033428677513598, 72.58340956318696), (23.147564894965342, 72.68198270271095)],
'Employee 11' : [(23.018845608393608, 72.56544677399661), (23.182791836465224, 72.62926060499345)],
'Employee 12' : [(23.009725167595104, 72.57767326241625), (23.201802188743773, 72.62031356538489)],
'Employee 13' : [(22.973016235540527, 72.48278495147159), (23.194097066748526, 72.62870306310008)],
'Employee 14' : [(23.075310320242078, 72.61548566976187), (23.194986007819992, 72.64718806455564)],
'Employee 15' : [(22.962583827699646, 72.59259316651803), (23.15601161293476, 72.6835067825237)],
'Employee 16' : [(23.028059405640064, 72.60034910593218), (23.181544301886685, 72.62128798446922)],
'Employee 17' : [(23.03311361407173, 72.53119062278128), (23.183943658453448, 72.63324300600767)],
'Employee 18' : [(23.07838496232549, 72.53356602914057), (23.193842707652248, 72.61215023485893)],
'Employee 19' : [(23.026707661454818, 72.60416282864408), (23.189773280337498, 72.62738375464941)],
'Employee 20' : [(23.01006321135809, 72.48580419374413), (23.179591320220243, 72.67333648082526)],
'Employee 21' : [(23.020937181995595, 72.5391054406913), (23.192928701477754, 72.64350899932546)],
'Employee 22' : [(23.03979786269015, 72.5337789752525), (23.186628236515006, 72.64715815895305)],
'Employee 23' : [(23.093964200342423, 72.49498716136624), (23.16017039946379, 72.62149139322744)],
'Employee 24' : [(23.095129055573572, 72.54005796759138), (23.20989835725416, 72.63350337832877)],
'Employee 25' : [(23.013227241533567, 72.52673825571952), (23.144194472835927, 72.71846531678821)],
'Employee 26' : [(23.057023618277768, 72.54079110622892), (23.188131105582556, 72.63562336147255)],
'Employee 27' : [(23.02451129271412, 72.57116664964992), (23.190666117301664, 72.58508733637102)],
'Employee 28' : [(23.077916432146043, 72.549427435601), (23.17740733370712, 72.64487683911047)],
'Employee 29' : [(23.006212441923953, 72.56930734339088), (23.200144074305364, 72.63587667045566)],
'Employee 30' : [(23.03011142740556, 72.55724700455447), (23.211125271684743, 72.61716367623401)],
'Employee 427' : [(23.248123609838355, 72.62991581249163), (23.18008549725734, 72.70798603576971)],
'Employee 428' : [(23.215592520756484, 72.64515095190785), (23.162715528528317, 72.63160865793614)],
'Employee 429' : [(23.2001613015048, 72.63819060166838), (23.207621641227714, 72.63508645442343)],
'Employee 430' : [(23.22455722126281, 72.64385064769742), (23.20427875643318, 72.64688911638899)],
'Employee 431' : [(23.220451798082994, 72.66187883254305), (23.15586042636135, 72.66020670338456)],
'Employee 432' : [(23.217496021406497, 72.64479667957907), (23.2015245876057, 72.6426045944769)],
'Employee 433' : [(23.21134008048458, 72.6062566430233), (23.170411832284486, 72.64253764137501)],
'Employee 434' : [(23.191374581766773, 72.69007105028992), (23.191249169811766, 72.70610465130802)],
'Employee 435' : [(23.19539832938242, 72.6540826311274), (23.136609671105017, 72.67465518530233)],
'Employee 436' : [(23.24480427021423, 72.62737000329442), (23.18536379390735, 72.6337450015259)],
'Employee 437' : [(23.23212349305858, 72.6069943275993), (23.157455670327668, 72.72440559358014)],
'Employee 438' : [(23.216649382028994, 72.63438910368369), (23.192223196803496, 72.63107640215915)],
'Employee 439' : [(23.21666694218264, 72.69752550986837), (23.19816610838539, 72.61573919433918)],
'Employee 440' : [(23.217261510584063, 72.64418818878491), (23.191502581319163, 72.61122885270684)],
'Employee 441' : [(23.215402511995816, 72.64155212760814), (23.176537245236364, 72.62274035545745)],
'Employee 442' : [(23.265321260218066, 72.64138735813275), (23.203092292666565, 72.60098877772162)],
'Employee 443' : [(23.18558915016619, 72.63909798170742), (23.206204694405482, 72.63414669685814)],
'Employee 444' : [(23.223654416772366, 72.63880299771031), (23.18589017749409, 72.6236762480996)],
'Employee 445' : [(23.238131025013438, 72.6402457596001), (23.156732491545018, 72.68484417455585)],
'Employee 446' : [(23.218010076015034, 72.64096813273476), (23.179491429187266, 72.62343374112339)],
'Employee 447' : [(23.24725830105125, 72.66154489797458), (23.174508936534924, 72.66392237541764)],
'Employee 448' : [(23.181832072905774, 72.64326381204894), (23.18709196405108, 72.58870865687929)],
'Employee 449' : [(23.222525835580782, 72.6374433174042), (23.192646255904343, 72.63066628018493)],
'Employee 450' : [(23.19029907596503, 72.62222216587773), (23.21738648788762, 72.632990889646)],
}

# Extract office and home locations
office_locations = [locations[1] for locations in employee_data.values()]
home_locations = [locations[0] for locations in employee_data.values()]

# Convert office locations to numpy array
office_locations_np = np.array(office_locations)
home_locations_np = np.array(home_locations)

# Perform KMeans clustering for office locations
kmeans_office = KMeans(n_clusters=6, random_state=42).fit(office_locations_np)
cluster_centers_office = kmeans_office.cluster_centers_
labels_office = kmeans_office.labels_

# Perform KMeans clustering for home locations
kmeans_home = KMeans(n_clusters=6, random_state=42).fit(home_locations_np)
cluster_centers_home = kmeans_home.cluster_centers_
labels_home = kmeans_home.labels_

# Generate unique colors for each cluster for office locations
cluster_colors_office = ['#' + ''.join(random.choices('0123456789ABCDEF', k=6)) for _ in range(len(cluster_centers_office))]

# Generate unique colors for each cluster for home locations
cluster_colors_home = ['#' + ''.join(random.choices('0123456789ABCDEF', k=6)) for _ in range(len(cluster_centers_home))]

# Plot each employee's office and home locations
employee_clusters_office = {}
for i, (employee, locations) in enumerate(employee_data.items()):
    home, office = locations
    home_color = cluster_colors_home[labels_home[i]]
    office_color = cluster_colors_office[labels_office[i]]
    folium.Marker(home, popup=f'{employee} Home (Cluster {labels_home[i]+1})', icon=folium.Icon(color=home_color)).add_to(m)
    folium.Marker(office, popup=f'{employee} Office (Cluster {labels_office[i]+1})', icon=folium.Icon(color=office_color)).add_to(m)
    if labels_office[i] not in employee_clusters_office:
        employee_clusters_office[labels_office[i]] = []
    employee_clusters_office[labels_office[i]].append(employee)

# Plot cluster centers with a radius of 6km for office locations
for i, center in enumerate(cluster_centers_office):
    folium.Circle(center, radius=6000, color=cluster_colors_office[i], fill=False).add_to(m)

# Print employees and their corresponding cluster for office locations
print("Office Clusters:")
for cluster_label, employees in employee_clusters_office.items():
    print(f"Cluster {cluster_label + 1}: {', '.join(employees)}")

# Print employees and their corresponding cluster for home locations
employee_clusters_home = {}
for i, (employee, locations) in enumerate(employee_data.items()):
    home, office = locations
    if labels_home[i] not in employee_clusters_home:
        employee_clusters_home[labels_home[i]] = []
    employee_clusters_home[labels_home[i]].append(employee)

print("\nHome Clusters:")
for cluster_label, employees in employee_clusters_home.items():
    print(f"Cluster {cluster_label + 1}: {', '.join(employees)}")

# Display the map
m

# Create a dictionary to store employee clusters
employee_clusters = {}

# Populate the dictionary with employee clusters
for i, (employee, locations) in enumerate(employee_data.items()):
    home_cluster = labels_home[i]
    office_cluster = labels_office[i]
    employee_clusters[employee] = (home_cluster + 1, office_cluster + 1)

# Sort employee_clusters based on the employee number
sorted_employee_clusters = sorted(employee_clusters.items(), key=lambda x: int(x[0].split()[1]))

# Print employees and their corresponding office and home clusters
employee_clusters_output = "\nEmployee Clusters:\n"
for employee, (home_cluster, office_cluster) in sorted_employee_clusters:
    employee_clusters_output += f'"{employee}": ({office_cluster}, {home_cluster}),\n'

# Store employee clusters output in RESULT dictionary
RESULT = {"Employee Clusters": employee_clusters_output}



coordinates_text = RESULT['Employee Clusters']
coordinates_list = coordinates_text.split("\n")[2:-1]
coordinates_dict = {k.strip('"'): eval(v) for k, v in [c.split(':') for c in coordinates_list]}

same_coordinates = {}
remaining_employees = []

for employee, coordinates in coordinates_dict.items():
    if coordinates in same_coordinates:
        same_coordinates[coordinates].append(employee)
    else:
        same_coordinates[coordinates] = [employee]

# Print employees with the same coordinates
print("Employees having equal (x, y) coordinates:")
for coordinates, employees_list in same_coordinates.items():
    if len(employees_list) > 1:
        print(f"Coordinates {coordinates}: {', '.join(employees_list)}")
    else:
        remaining_employees.extend(employees_list)

# Print remaining employees
print("\nRemaining Employees:")
print(', '.join(remaining_employees))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-1-a69dde028fc6>:493: UserWarning: color argument of Icon should be one of: {'red', 'orange', 'white', 'beige', 'pink', 'darkpurple', 'green', 'darkgreen', 'lightgray', 'darkred', 'black', 'gray', 'cadetblue', 'lightblue', 'purple', 'darkblue', 'lightgreen', 'blue', 'lightred'}.
#   folium.Marker(home, popup=f'{employee} Home (Cluster {labels_home[i]+1})', icon=folium.Icon(color=home_color)).add_to(m)
# ...

# %%
#HOMEorder
import googlemaps
from googlemaps.exceptions import ApiError  # Corrected import statement

# Google Maps API Key
API_KEY = "AIzaSyBNUqfZQM-9yCPoAwDBjT3e37MLMCcLrWU"

# Initialize Google Maps client
gmaps = googlemaps.Client(key=API_KEY)

# Function to calculate road distance from one location to another
def calculate_distance(location1, location2):
    try:
        directions = gmaps.directions(location1, location2, mode="driving")
        distance_in_meters = directions[0]['legs'][0]['distance']['value']
        distance_in_km = distance_in_meters / 1000  # Convert distance to kilometers
        return distance_in_km
    except ApiError as e:
        print(f"Error calculating distance between {location1} and {location2}: {e}")
        return float('inf')  # Return a large value to indicate that the distance is not available

# Function to calculate distance from each employee to the office
def calculate_distance_to_office(locations):
    office_location = locations['office']  # Get office location
    distances = {}
    for employee, location in locations.items():
        if employee != 'office':  # Exclude office location
            distance = calculate_distance(location, office_location)
            distances[employee] = distance
    return distances

# Employee locations (including latitude and longitude)
employee_locations = {
'Employee 331' : (23.204274793539316, 72.61996634258948),
'Employee 337' : (23.229743984794144, 72.63684495073814),
'Employee 341' : (23.206120667309495, 72.64187512923147),
'Employee 358' : (23.173115106637358, 72.63948664725355),
'Employee 362' : (23.18986625033276, 72.60617924222613),
'Employee 412' : (23.242854996366045, 72.64845760677466),
'Employee 413' : (23.234018772457272, 72.6520453851032),
'Employee 416' : (23.21406165829817, 72.63249139035001),
'Employee 417' : (23.21936739226067, 72.65034262855805),
'Employee 420' : (23.24540528305283, 72.63969482796861),
'Employee 423' : (23.263328528554958, 72.6543520232059),
'Employee 424' : (23.210677480314285, 72.62784079242532),
'Employee 431' : (23.220451798082994, 72.66187883254305),
'Employee 435' : (23.19539832938242, 72.6540826311274),
    'office': (23.136609671105017, 72.67465518530233)
}

# Calculate road distance to office from each employee
distances_to_office = calculate_distance_to_office(employee_locations)

# Sort employees by distance to office
sorted_employees = sorted(distances_to_office, key=distances_to_office.get, reverse=True)

# Select the farthest employee
farthest_employee = sorted_employees[0]

# Select other employees sorted by their distance from the farthest employee
sorted_other_employees = sorted(employee_locations.keys(), key=lambda x: calculate_distance(employee_locations[farthest_employee], employee_locations[x]))

# Print the employees in order
print("Employees in order:")
print(farthest_employee)  # Print the farthest employee first
for employee in sorted_other_employees:
    if employee != farthest_employee:
        print(employee)
# Print the employees in order along with their coordinates
print("Employees in order:")
print(f"{farthest_employee} - Coordinates: {employee_locations[farthest_employee]}")  # Print the farthest employee first
for employee in sorted_other_employees:
    if employee != farthest_employee:
        print(f"{employee} - Coordinates: {employee_locations[employee]}")

# Print the coordinates of the office
print("Office Coordinates:")
print(f"Office - Coordinates: {employee_locations['office']}")
# Out:
# Employees in order:
# Employee 423
# Employee 420
# Employee 412
# Employee 413
# Employee 337
# Employee 417
# Employee 416
# Employee 424
# Employee 431
# Employee 341
# Employee 331
# Employee 435
# Employee 362
# Employee 358
# office
# Employees in order:
# Employee 423 - Coordinates: (23.263328528554958, 72.6543520232059)
# Employee 420 - Coordinates: (23.24540528305283, 72.63969482796861)
# Employee 412 - Coordinates: (23.242854996366045, 72.64845760677466)
# Employee 413 - Coordinates: (23.234018772457272, 72.6520453851032)
# Employee 337 - Coordinates: (23.229743984794144, 72.63684495073814)
# Employee 417 - Coordinates: (23.21936739226067, 72.65034262855805)
# Employee 416 - Coordinates: (23.21406165829817, 72.63249139035001)
# Employee 424 - Coordinates: (23.210677480314285, 72.62784079242532)
# Employee 431 - Coordinates: (23.220451798082994, 72.66187883254305)
# Employee 341 - Coordinates: (23.206120667309495, 72.64187512923147)
# ...

# %%
#OFFICEorder
import googlemaps
from googlemaps.exceptions import ApiError  # Corrected import statement

# Google Maps API Key
API_KEY = "AIzaSyBNUqfZQM-9yCPoAwDBjT3e37MLMCcLrWU"

# Initialize Google Maps client
gmaps = googlemaps.Client(key=API_KEY)

# Function to calculate road distance from one location to another
def calculate_distance(location1, location2):
    try:
        directions = gmaps.directions(location1, location2, mode="driving")
        distance_in_meters = directions[0]['legs'][0]['distance']['value']
        distance_in_km = distance_in_meters / 1000  # Convert distance to kilometers
        return distance_in_km
    except ApiError as e:
        print(f"Error calculating distance between {location1} and {location2}: {e}")
        return float('inf')  # Return a large value to indicate that the distance is not available

# Function to calculate distance from each employee to the office
def calculate_distance_to_office(locations):
    office_location = locations['office']  # Get office location
    distances = {}
    for employee, location in locations.items():
        if employee != 'office':  # Exclude office location
            distance = calculate_distance(location, office_location)
            distances[employee] = distance
    return distances

# Employee locations (including latitude and longitude)
employee_locations = {
'Employee 331' : (23.204274793539316, 72.61996634258948),
'Employee 337' : (23.229743984794144, 72.63684495073814),
'Employee 341' : (23.206120667309495, 72.64187512923147),
'Employee 358' : (23.173115106637358, 72.63948664725355),
'Employee 362' : (23.18986625033276, 72.60617924222613),
'Employee 412' : (23.242854996366045, 72.64845760677466),
'Employee 413' : (23.234018772457272, 72.6520453851032),
'Employee 416' : (23.21406165829817, 72.63249139035001),
'Employee 417' : (23.21936739226067, 72.65034262855805),
'Employee 420' : (23.24540528305283, 72.63969482796861),
'Employee 423' : (23.263328528554958, 72.6543520232059),
'Employee 424' : (23.210677480314285, 72.62784079242532),
'Employee 431' : (23.220451798082994, 72.66187883254305),
'Employee 435' : (23.19539832938242, 72.6540826311274),
    'office': (23.136609671105017, 72.67465518530233)
}

# Calculate road distance to office from each employee
distances_to_office = calculate_distance_to_office(employee_locations)

# Sort employees by distance to office
sorted_employees = sorted(distances_to_office, key=distances_to_office.get, reverse=True)

# Select the farthest employee
farthest_employee = sorted_employees[0]

# Select other employees sorted by their distance from the farthest employee
sorted_other_employees = sorted(employee_locations.keys(), key=lambda x: calculate_distance(employee_locations[farthest_employee], employee_locations[x]))

# Print the employees in order
print("Employees in order:")
print(farthest_employee)  # Print the farthest employee first
for employee in sorted_other_employees:
    if employee != farthest_employee:
        print(employee)
# Print the employees in order along with their coordinates
print("Employees in order:")
print(f"{farthest_employee} - Coordinates: {employee_locations[farthest_employee]}")  # Print the farthest employee first
for employee in sorted_other_employees:
    if employee != farthest_employee:
        print(f"{employee} - Coordinates: {employee_locations[employee]}")

# Print the coordinates of the office
print("Office Coordinates:")
print(f"Office - Coordinates: {employee_locations['office']}")

# %%
pip install googlemaps
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40712 sha256=fe12e23d510b5e41c0fc4255b4d710d6393a65209af1e7c0cae5c568d7333983
#   Stored in directory: /root/.cache/pip/wheels/17/f8/79/999d5d37118fd35d7219ef57933eb9d09886c4c4503a800f84
# Successfully built googlemaps
# ...

# %%
import folium
from folium import plugins
import numpy as np
from scipy.spatial import distance_matrix

# Sample data
employee_data = {
    'Employee 18': [(23.0185, 72.5379), (23.0835, 72.5787)],
    'Employee 24': [(23.0411, 72.5301), (23.0932, 72.5693)],
    'Employee 26': [(23.0534, 72.5266), (23.0845, 72.5701)],
    'Employee 29': [(23.037, 72.5356), (23.0846, 72.5692)],

}

# Extract home and office locations
home_locations = [data[0] for data in employee_data.values()]
office_locations = [data[1] for data in employee_data.values()]  # All offices

# Calculate distance matrix for home locations
distance_matrix_home = distance_matrix(home_locations, home_locations)

# Nearest Neighbor Algorithm for Traveling Salesman Problem for home locations
def nearest_neighbor_home(dist_matrix, start_index):
    n = len(dist_matrix)
    unvisited = set(range(n))
    unvisited.remove(start_index)
    current_index = start_index
    path = [current_index]

    while unvisited:
        nearest_index = min(unvisited, key=lambda x: dist_matrix[current_index][x])
        path.append(nearest_index)
        unvisited.remove(nearest_index)
        current_index = nearest_index

    path.append(start_index)  # Return to start
    return path

# Find optimal path for connecting homes
start_index_home = np.argmax(np.sum(distance_matrix_home, axis=1))  # Start from the farthest home
optimal_path_home = nearest_neighbor_home(distance_matrix_home, start_index_home)

# Create map centered around Ahmedabad, India
m = folium.Map(location=[23.0225, 72.5714], zoom_start=12)

# Add home markers with selected employees
for i, (location, employee) in enumerate(zip(home_locations, employee_data.keys())):
    folium.Marker(location, popup=f'{employee} Home').add_to(m)

# Add route using the optimal path for connecting homes
optimal_locations_home = [home_locations[i] for i in optimal_path_home]
route_home = plugins.AntPath(locations=optimal_locations_home, dash_array=[10, 20], delay=800, color='blue')
m.add_child(route_home)

# Add office markers
for location in office_locations:
    folium.Marker(location, popup='Office', icon=folium.Icon(color='green')).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import googlemaps
from googlemaps.exceptions import ApiError

# Google Maps API Key
API_KEY = "AIzaSyBNUqfZQM-9yCPoAwDBjT3e37MLMCcLrWU"

# Initialize Google Maps client
gmaps = googlemaps.Client(key=API_KEY)

# Function to calculate road distance from one location to another
def calculate_distance(location1, location2):
    try:
        directions = gmaps.directions(location1, location2, mode="driving")
        distance_in_meters = directions[0]['legs'][0]['distance']['value']
        distance_in_km = distance_in_meters / 1000  # Convert distance to kilometers
        return distance_in_km
    except ApiError as e:
        print(f"Error calculating distance between {location1} and {location2}: {e}")
        return float('inf')  # Return a large value to indicate that the distance is not available

def nearest_neighbor(coordinates):
    # Initializing lists to keep track of the order and the remaining locations
    order = []
    remaining_locations = coordinates.copy()

    # Start from the first location
    current_location = list(remaining_locations.keys())[0]
    order.append(current_location)
    remaining_locations.pop(current_location)

    while remaining_locations:
        # Find the nearest location to the current_location
        nearest_location = None
        min_distance = float('inf')
        for location, coords in remaining_locations.items():
            distance = calculate_distance(coordinates[current_location], coords)
            if distance < min_distance:
                min_distance = distance
                nearest_location = location

        # Move to the nearest location
        order.append(nearest_location)
        remaining_locations.pop(nearest_location)
        current_location = nearest_location

    # Return the final order
    return order

# Example usage
coordinates = {
    'Employee 1': (23.1729156, 72.6389547),
'Employee 4': (23.1108436, 72.587488),
'Employee 39': (23.1118962, 72.5900292),
'Employee 52': (23.1731869, 72.63776899999999),
'Employee 65': (23.1852636, 72.6166476),
'Employee 79': (23.127763, 72.5853745),
'Employee 82': (23.2035707, 72.6294037),
'Employee 88': (23.1235038, 72.6219893),
'Employee 90': (23.110516, 72.549785),
'Employee 95': (23.0698417, 72.6730365),
'Employee 98': (23.1792012, 72.6397611),
'Employee 108': (23.1612837, 72.5408937),
}

route = nearest_neighbor(coordinates)
print("Route:", route)
# Out:
# Route: ['Employee 1', 'Employee 52', 'Employee 98', 'Employee 65', 'Employee 82', 'Employee 88', 'Employee 39', 'Employee 4', 'Employee 79', 'Employee 90', 'Employee 108', 'Employee 95']

# %%
import googlemaps
from googlemaps.exceptions import ApiError  # Corrected import statement

# Google Maps API Key
API_KEY = "AIzaSyBNUqfZQM-9yCPoAwDBjT3e37MLMCcLrWU"

# Initialize Google Maps client
gmaps = googlemaps.Client(key=API_KEY)

# Function to calculate road distance from one location to another
def calculate_distance(location1, location2):
    try:
        directions = gmaps.directions(location1, location2, mode="driving")
        distance_in_meters = directions[0]['legs'][0]['distance']['value']
        distance_in_km = distance_in_meters / 1000  # Convert distance to kilometers
        return distance_in_km
    except ApiError as e:
        print(f"Error calculating distance between {location1} and {location2}: {e}")
        return float('inf')  # Return a large value to indicate that the distance is not available

# Function to calculate distance from each employee to the farthest employee
def calculate_distance_to_farthest(locations, farthest_employee):
    distances = {}
    for employee, location in locations.items():
        if employee != farthest_employee:  # Exclude farthest employee
            distance = calculate_distance(location, locations[farthest_employee])
            distances[employee] = distance
    return distances

# Employee locations (including latitude and longitude)
employee_locations = {
    'Employee 1': (23.1729156, 72.6389547),
    'Employee 4': (23.1108436, 72.587488),
    'Employee 39': (23.1118962, 72.5900292),
    'Employee 52': (23.1731869, 72.63776899999999),
    'Employee 65': (23.1852636, 72.6166476),
    'Employee 79': (23.127763, 72.5853745),
    'Employee 82': (23.2035707, 72.6294037),
    'Employee 88': (23.1235038, 72.6219893),
    'Employee 90': (23.110516, 72.549785),
    'Employee 95': (23.0698417, 72.6730365),
    'Employee 98': (23.1792012, 72.6397611),
    'Employee 108': (23.1612837, 72.5408937)
}

# Select the farthest employee
farthest_employee = max(employee_locations, key=lambda x: max([calculate_distance(employee_locations[x], loc) for loc in employee_locations.values()]))

# Calculate road distance to the farthest employee from each employee
distances_to_farthest = calculate_distance_to_farthest(employee_locations, farthest_employee)

# Sort employees by distance to the farthest employee
sorted_employees = sorted(distances_to_farthest, key=distances_to_farthest.get, reverse=True)

# Print the employees in order
print("Employees in order:")
print(farthest_employee)  # Print the farthest employee first
for employee in sorted_employees:
    if employee != farthest_employee:
        print(employee)
# Out:
# Employees in order:
# Employee 90
# Employee 95
# Employee 1
# Employee 52
# Employee 98
# Employee 82
# Employee 65
# Employee 88
# Employee 4
# Employee 39
# Employee 79
# Employee 108

# %%
pip install googlemaps
